# %% [markdown]
# # 600 l/mm Blue
# Lamp | Usable | Comments
# --- | --- | ---
# Ne | No | Too few lines and not conveniently located
# FeHeAr | No | Large background noise
# Ar | No | Too much background
# HgAr | Yes | Best
# CuHeAr | Yes | A bit too crowded
# HgArNe | Yes| Prefer HgAr

# %%
from ccdproc import CCDData

import glob
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (14, 6)

def _plot_lamps(file_list):
    for _file in file_list:
        ccd = CCDData.read(_file, unit='adu')
        fig, ax = plt.subplots(num=_file)
        ax.set_title(_file)
        ax.plot(ccd.data, label='Lamp: {:s} exposed {:.1f} Seconds'.format(ccd.header['OBJECT'], ccd.header['EXPTIME']))
        ax.legend()
        plt.show()

# %%
f = glob.glob('files/*600Blue*fits')
_plot_lamps(file_list=f)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %% [markdown]
# # Results

# %%
for _f in f:
    print(_f)
# Out:
# files/goodman_comp_600Blue_Ne.fits
# files/goodman_comp_600Blue_FeHeAr.fits
# files/goodman_comp_600Blue_Ar.fits
# files/goodman_comp_600Blue_HgAr.fits
# files/goodman_comp_600Blue_CuHeAr.fits
# files/goodman_comp_600Blue_HgArNe.fits
