# %% [markdown]
# # Analysis of Comparison Lamps Usability

# %% [markdown]
# # 600 l/mm Red
#
# **_Ar_ seems to be the only element contributing with lines**
#
# Lamp   | Usable | Comments
# ---    | ---    | ---
# Ne     | Yes    | Coverage less than ideal
# FeHeAr | Yes    | None
# Ar     | Yes    | Best
# HgAr   | Yes    | None
# CuHeAr | Yes    | None
# HgArNe | Yes    | None

# %%
from ccdproc import CCDData

import glob
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (14, 6)

def _plot_lamps(file_list):
    for _file in file_list:
        ccd = CCDData.read(_file, unit='adu')
        fig, ax = plt.subplots(num=_file)
        ax.set_title(_file)
        ax.plot(ccd.data, label='Lamp: {:s} exposed {:.1f} Seconds'.format(ccd.header['OBJECT'], ccd.header['EXPTIME']))
        ax.legend()
        plt.show()

# %%
files_list = glob.glob('files/*600Red*fits')
_plot_lamps(file_list=files_list)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
for _f in files_list:
    print(_f)
# Out:
# files/goodman_comp_600Red_GG495_Ar.fits
# files/goodman_comp_600Red_GG495_HgAr.fits
# files/goodman_comp_600Red_GG495_Ne.fits
# files/goodman_comp_600Red_GG495_FeHeAr.fits
# files/goodman_comp_600Red_GG495_HgArNe.fits
# files/goodman_comp_600Red_GG495_CuHeAr.fits
