# %%
import glob
import os

files = glob.glob('/user/simon/jupyter/data/raw/*fits')
for file in files:
    print(file)
# Out:
# /user/simon/jupyter/data/raw/0086_CuHeAr_G1200M2_slit103.fits
# /user/simon/jupyter/data/raw/0171_HD177409_G1200M2_slit103.fits
# /user/simon/jupyter/data/raw/0108_CuHeAr_G1200M2_slit103.fits
# /user/simon/jupyter/data/raw/0085_HD177409_G1200M2_slit103.fits
# /user/simon/jupyter/data/raw/0170_CuHeAr_G1200M2_slit103.fits
# /user/simon/jupyter/data/raw/0109_HD177409_G1200M2_slit103.fits

# %%
from ccdproc import CCDData

for file in files:
    ccd = CCDData.read(file, unit='adu')
    print(ccd.header['DATE'], os.path.basename(file))
# Out:
# 2017-06-13 0086_CuHeAr_G1200M2_slit103.fits
# 2017-06-12 0171_HD177409_G1200M2_slit103.fits
# 2017-06-11 0108_CuHeAr_G1200M2_slit103.fits
# 2017-06-13 0085_HD177409_G1200M2_slit103.fits
# 2017-06-12 0170_CuHeAr_G1200M2_slit103.fits
# 2017-06-11 0109_HD177409_G1200M2_slit103.fits

# %%
-
