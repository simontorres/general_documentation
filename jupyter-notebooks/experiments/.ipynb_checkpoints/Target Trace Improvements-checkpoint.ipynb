# %%
full_path = '/user/simon/data/soar/work/aeon/2019-08-06_rachel/RED/cfsto_0180_OGLE-2019-BLG-0747_obs1-07-08-2019.fits'

from ccdproc import CCDData

ccd = CCDData.read(full_path, unit='adu')
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
import matplotlib
print(matplotlib.rcParams['backend'])
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(18,10))

ax.imshow(ccd.data, cmap='gray', clim=(0, 500))
plt.show()
# Out:
# module://ipykernel.pylab.backend_inline

# %%
import numpy as np

median = np.median(ccd.data, axis=0)

fig, ax = plt.subplots(figsize=(18, 10))
ax.plot(median)
plt.show()

# %%
median_subtracted = ccd.data - median[:None]

# %%
fig, ax = plt.subplots(figsize=(18,10))
ax.imshow(median_subtracted, cmap='gray', clim=(0, 500))
ax.set_title("Median subtracted data.")
plt.show()

fig, ax = plt.subplots(figsize=(18, 10))
ax.imshow(ccd.data, cmap='gray', clim=(0, 500))
ax.set_title('Original Data')
plt.show()

# %%
ccd_spatial_median = np.median(ccd.data, axis=1)
cleaned_spatial_median = np.median(median_subtracted, axis=1)

fig,ax = plt.subplots(figsize=(18, 10))

ax.plot(ccd_spatial_median, color='b', label='CCD')
ax.plot(cleaned_spatial_median, color='r', label='cleaned')
plt.legend(loc='best')
plt.show()

# %%
import goodman_pipeline
print(goodman_pipeline.__version__)
# Out:
# [17:37:25][I]: Starting Goodman HTS Pipeline Log
# [17:37:25][I]: Local Time    : 2019-08-20 17:37:25.687941
# [17:37:25][I]: Universal Time: 2019-08-20 21:37:25.688608
# [17:37:27][I]: Pipeline Version: 1.2.1 (latest)
# 1.2.1

# %%
from goodman_pipeline.core import identify_targets

copy_ccd = ccd.copy()
copy_ccd.data = median_subtracted
identified_targets = identify_targets(ccd=copy_ccd, fit_model='gaussian', background_threshold=1, nfind=30, plots=False)
# Out:
# [17:37:27][I]: Searching spectroscopic targets in file: cfsto_0180_OGLE-2019-BLG-0747_obs1-07-08-2019.fits
# [17:37:27][I]: Fitting Linear1D model to spatial profile to detect background shape
# [17:37:27][I]: Subtracting background shape and level spatial profile for better target identification
# [17:37:27][I]: Finding all peaks in spatial profile
# [17:37:27][I]: Selecting the 30 most intense peaks out of 29 found
# [17:37:27][I]: Validating peaks by setting threshold 1 times the background level 329.96
# [17:37:27][I]: Selecting peak: Centered: 28.0 Intensity 4100.862
# [17:37:27][I]: Selecting peak: Centered: 477.0 Intensity 3036.127
# [17:37:27][I]: Selecting peak: Centered: 751.0 Intensity 1226.917
# [17:37:27][I]: Selecting peak: Centered: 525.0 Intensity 1083.402
# [17:37:27][I]: Selecting peak: Centered: 363.0 Intensity 1034.415
# [17:37:27][I]: Selecting peak: Centered: 784.0 Intensity 958.443
# [17:37:27][I]: Selecting peak: Centered: 443.0 Intensity 909.618
# [17:37:27][I]: Selecting peak: Centered: 593.0 Intensity 903.958
# [17:37:27][I]: Selecting peak: Centered: 733.0 Intensity 844.743
# [17:37:27][I]: Selecting peak: Centered: 426.0 Intensity 760.993
# [17:37:27][I]: Selecting peak: Centered: 531.0 Intensity 647.734
# [17:37:27][I]: Selecting peak: Centered: 319.0 Intensity 609.477
# [17:37:27][I]: Selecting peak: Centered: 227.0 Intensity 583.551
# [17:37:27][I]: Selecting peak: Centered: 419.0 Intensity 576.953
# [17:37:27][I]: Selecting peak: Centered: 643.0 Intensity 560.870
# [17:37:27][I]: Selecting peak: Centered: 676.0 Intensity 554.387
# [17:37:27][I]: Selecting peak: Centered: 402.0 Intensity 521.405
# [17:37:27][I]: Selecting peak: Centered: 455.0 Intensity 519.072
# [17:37:27][I]: Selecting peak: Centered: 155.0 Intensity 345.068
# [17:37:27][I]: Fitting 'Gaussian1D' to spatial profile of targets.
# [17:37:27][I]: Recording target centered at: 28.38, stddev: 1.46
# [17:37:27][I]: Recording target centered at: 476.61, stddev: 1.56
# [17:37:27][I]: Recording target centered at: 750.87, stddev: 1.41
# [17:37:27][I]: Recording target centered at: 526.41, stddev: 5.17
# [17:37:27][I]: Recording target centered at: 362.93, stddev: 1.35
# [17:37:27][I]: Recording target centered at: 784.22, stddev: 1.74
# [17:37:27][I]: Recording target centered at: 442.99, stddev: 1.87
# [17:37:27][I]: Recording target centered at: 591.98, stddev: 2.40
# [17:37:27][I]: Recording target centered at: 732.42, stddev: 1.97
# [17:37:27][I]: Recording target centered at: 423.61, stddev: 5.65
# [17:37:27][I]: Recording target centered at: 526.41, stddev: 5.17
# [17:37:27][I]: Recording target centered at: 318.86, stddev: 1.62
# [17:37:27][I]: Recording target centered at: 226.74, stddev: 1.43
# [17:37:27][E]: Discarding target with stddev: 13224.487
# [17:37:27][I]: Recording target centered at: 642.70, stddev: 1.73
# [17:37:27][I]: Recording target centered at: 675.53, stddev: 1.55
# [17:37:27][I]: Recording target centered at: 401.75, stddev: 1.29
# [17:37:27][I]: Recording target centered at: 455.20, stddev: 1.51
# [17:37:27][I]: Recording target centered at: 154.88, stddev: 1.79
# [17:37:27][I]: Identified 18 targets

# %%
print(identified_targets)
# Out:
# [<Gaussian1D(amplitude=4134.21127934, mean=28.38358594, stddev=1.46200744, name='Gaussian_28')>, <Gaussian1D(amplitude=2904.08863154, mean=476.61336923, stddev=1.5553344, name='Gaussian_477')>, <Gaussian1D(amplitude=1166.91327561, mean=750.87118654, stddev=1.4060056, name='Gaussian_751')>, <Gaussian1D(amplitude=681.76102986, mean=526.41210655, stddev=5.16760292, name='Gaussian_525')>, <Gaussian1D(amplitude=1006.72137823, mean=362.92855834, stddev=1.35312436, name='Gaussian_363')>, <Gaussian1D(amplitude=952.91250636, mean=784.22144802, stddev=1.73651226, name='Gaussian_784')>, <Gaussian1D(amplitude=867.66120443, mean=442.99387706, stddev=1.87227064, name='Gaussian_443')>, <Gaussian1D(amplitude=720.12321274, mean=591.97736545, stddev=2.4007108, name='Gaussian_593')>, <Gaussian1D(amplitude=771.82949279, mean=732.41932888, stddev=1.96613455, name='Gaussian_733')>, <Gaussian1D(amplitude=398.8338166, mean=423.60682216, stddev=5.64940221, name='Gaussian_426')>, <Gaussian1D(amplitude=681.73844642, mean=526.41255025, stddev=5.16794399, name='Gaussian_531')>, <Gaussian1D(amplitude=595.2551208, mean=318.86027269, stddev=1.62196253, name='Gaussian_319')>, <Gaussian1D(amplitude=582.99704285, mean=226.74415507, stddev=1.42680588, name='Gaussian_227')>, <Gaussian1D(amplitude=519.1219086, mean=642.69726357, stddev=1.73259834, name='Gaussian_643')>, <Gaussian1D(amplitude=539.29584686, mean=675.53267488, stddev=1.54883685, name='Gaussian_676')>, <Gaussian1D(amplitude=530.61025005, mean=401.75333468, stddev=1.29418971, name='Gaussian_402')>, <Gaussian1D(amplitude=520.42711014, mean=455.20340885, stddev=1.51224623, name='Gaussian_455')>, <Gaussian1D(amplitude=323.84722416, mean=154.87801251, stddev=1.78677922, name='Gaussian_155')>]

# %%
from goodman_pipeline.core import trace_targets
all_traces_cleaned = trace_targets(ccd=copy_ccd, target_list=identified_targets, nfwhm=2, plots=False)
# Out:
# [17:37:28][I]: Target tracing RMS error: 0.250
# [17:37:28][I]: Target tracing RMS error: 0.153
# [17:37:28][I]: Target tracing RMS error: 0.234
# [17:37:28][I]: Target tracing RMS error: 0.000
# [17:37:29][I]: Target tracing RMS error: 0.124
# [17:37:29][I]: Target tracing RMS error: 0.233
# [17:37:29][I]: Target tracing RMS error: 0.215
# [17:37:29][I]: Target tracing RMS error: 0.404
# [17:37:29][I]: Target tracing RMS error: 0.263
# [17:37:29][I]: Target tracing RMS error: 3.437
# [17:37:30][I]: Target tracing RMS error: 0.000
# [17:37:30][I]: Target tracing RMS error: 0.164
# [17:37:30][I]: Target tracing RMS error: 0.174
# [17:37:30][I]: Target tracing RMS error: 0.186
# [17:37:30][I]: Target tracing RMS error: 0.187
# [17:37:31][I]: Target tracing RMS error: 0.169
# [17:37:31][I]: Target tracing RMS error: 0.234
# [17:37:31][I]: Target tracing RMS error: 0.209

# %%
from colorama import Fore

for trace,  profile, trace_info in all_traces_cleaned:
    info = "c0 = {:06.2f} c1 = {: .5f} c2 = {: .3E} Center = {:06.2f} RMS = {:.4f}".format(trace.c0.value, 
                                                                                trace.c1.value,
                                                                                trace.c2.value, 
                                                                                profile.mean.value, 
                                                                                trace_info['GSP_TERR'][0])
    if trace_info['GSP_TERR'][0] > 3:
        print(Fore.RED + info)
    elif trace_info['GSP_TERR'][0] == 0.:
        print(Fore.BLUE + info)
    else:
        print(Fore.BLACK + info)
# Out:
# c0 = 026.57 c1 =  0.00330 c2 = -1.117E-06 Center = 028.38 RMS = 0.2497
# c0 = 475.75 c1 =  0.00097 c2 = -1.377E-07 Center = 476.61 RMS = 0.1534
# c0 = 749.83 c1 =  0.00071 c2 =  1.957E-07 Center = 750.87 RMS = 0.2339
# c0 = 525.00 c1 = -0.00000 c2 =  3.354E-21 Center = 526.41 RMS = 0.0000
# c0 = 361.70 c1 =  0.00171 c2 = -5.398E-07 Center = 362.93 RMS = 0.1239
# c0 = 783.68 c1 =  0.00019 c2 =  3.196E-07 Center = 784.22 RMS = 0.2334
# c0 = 442.28 c1 =  0.00114 c2 = -9.617E-08 Center = 442.99 RMS = 0.2153
# c0 = 590.49 c1 =  0.00295 c2 = -6.743E-07 Center = 591.98 RMS = 0.4042
# c0 = 731.99 c1 =  0.00090 c2 =  6.130E-08 Center = 732.42 RMS = 0.2629
# c0 = 454.52 c1 = -0.02119 c2 =  2.964E-06 Center = 423.61 RMS = 3.4371
# c0 = 525.00 c1 = -0.00000 c2 =  3.354E-21 Center = 526.41 RMS = 0.0000
# c0 = 317.59 c1 =  0.00160 c2 = -4.412E-07 Center = 318.86 RMS = 0.1642
# c0 = 225.52 c1 =  0.00163 c2 = -4.302E-07 Center = 226.74 RMS = 0.1742
# c0 = 641.81 c1 =  0.00043 c2 =  1.659E-07 Center = 642.70 RMS = 0.1859
# c0 = 674.76 c1 =  0.00062 c2 =  7.486E-08 Center = 675.53 RMS = 0.1871
# c0 = 400.66 c1 =  0.00128 c2 = -2.810E-07 Center = 401.75 RMS = 0.1694
# c0 = 454.11 c1 =  0.00118 c2 = -8.589E-08 Center = 455.20 RMS = 0.2339
# c0 = 153.27 c1 =  0.00228 c2 = -7.290E-07 Center = 154.88 RMS = 0.2088

# %% [markdown]
# ## Notes
# - Targets in blue are repeated, see plots below.

# %%
all_traces = trace_targets(ccd=ccd, target_list=identified_targets, nfwhm=2, plots=False)
# Out:
# [17:37:31][I]: Target tracing RMS error: 0.273
# [17:37:31][I]: Target tracing RMS error: 0.153
# [17:37:31][I]: Target tracing RMS error: 0.235
# [17:37:32][I]: Target tracing RMS error: 0.000
# [17:37:32][I]: Target tracing RMS error: 0.125
# [17:37:32][I]: Target tracing RMS error: 0.237
# [17:37:32][I]: Target tracing RMS error: 0.211
# [17:37:32][I]: Target tracing RMS error: 0.426
# [17:37:33][I]: Target tracing RMS error: 0.264
# [17:37:33][I]: Target tracing RMS error: 3.423
# [17:37:33][I]: Target tracing RMS error: 0.000
# [17:37:33][I]: Target tracing RMS error: 0.166
# [17:37:33][I]: Target tracing RMS error: 0.179
# [17:37:33][I]: Target tracing RMS error: 0.180
# [17:37:34][I]: Target tracing RMS error: 0.183
# [17:37:34][I]: Target tracing RMS error: 0.163
# [17:37:34][I]: Target tracing RMS error: 0.229
# [17:37:34][I]: Target tracing RMS error: 0.212

# %%
print(all_traces)
# Out:
# [[<Polynomial1D(2, c0=26.51526769, c1=0.00354788, c2=-0.00000128)>, <Gaussian1D(amplitude=4134.21127934, mean=28.38358594, stddev=1.46200744, name='Gaussian_28')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [26.515267691634293, 'Parameter c0']), ('GSP_TC01', [0.003547877042450336, 'Parameter c1']), ('GSP_TC02', [-1.2825814830870674e-06, 'Parameter c2']), ('GSP_TERR', [0.27301583012822705, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=475.74908588, c1=0.00097163, c2=-0.00000014)>, <Gaussian1D(amplitude=2904.08863154, mean=476.61336923, stddev=1.5553344, name='Gaussian_477')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [475.7490858755069, 'Parameter c0']), ('GSP_TC01', [0.0009716297183988837, 'Parameter c1']), ('GSP_TC02', [-1.377104001174064e-07, 'Parameter c2']), ('GSP_TERR', [0.1533588763388854, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=749.82836352, c1=0.00072951, c2=0.00000019)>, <Gaussian1D(amplitude=1166.91327561, mean=750.87118654, stddev=1.4060056, name='Gaussian_751')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [749.8283635193067, 'Parameter c0']), ('GSP_TC01', [0.0007295051543577402, 'Parameter c1']), ('GSP_TC02', [1.9067695828003099e-07, 'Parameter c2']), ('GSP_TERR', [0.2352403594262603, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=525., c1=0., c2=-0.)>, <Gaussian1D(amplitude=681.76102986, mean=526.41210655, stddev=5.16760292, name='Gaussian_525')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [525.0, 'Parameter c0']), ('GSP_TC01', [1.0643471949704632e-16, 'Parameter c1']), ('GSP_TC02', [-5.265957106300329e-20, 'Parameter c2']), ('GSP_TERR', [0.0, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=361.69820017, c1=0.00170055, c2=-0.00000054)>, <Gaussian1D(amplitude=1006.72137823, mean=362.92855834, stddev=1.35312436, name='Gaussian_363')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [361.6982001665884, 'Parameter c0']), ('GSP_TC01', [0.0017005532938463505, 'Parameter c1']), ('GSP_TC02', [-5.356981129309491e-07, 'Parameter c2']), ('GSP_TERR', [0.12501907815105734, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=783.6787345, c1=0.00016889, c2=0.00000034)>, <Gaussian1D(amplitude=952.91250636, mean=784.22144802, stddev=1.73651226, name='Gaussian_784')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [783.6787344987617, 'Parameter c0']), ('GSP_TC01', [0.00016889221182159186, 'Parameter c1']), ('GSP_TC02', [3.368294927687482e-07, 'Parameter c2']), ('GSP_TERR', [0.23679521733456246, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=442.44754564, c1=0.00082484, c2=0.00000002)>, <Gaussian1D(amplitude=867.66120443, mean=442.99387706, stddev=1.87227064, name='Gaussian_443')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model used to fit target trace']), ('GSP_TC00', [442.4475456362226, 'Parameter c0']), ('GSP_TC01', [0.000824844946915589, 'Parameter c1']), ('GSP_TC02', [2.488806285490816e-08, 'Parameter c2']), ('GSP_TERR', [0.2107478698303273, 'RMS error of target trace'])])], [<Polynomial1D(2, c0=590.22997004, c1=0.00335314, c2=-0.00000081)>, <Gaussian1D(amplitude=720.12321274, mean=591.97736545, stddev=2.4007108, name='Gaussian_593')>, OrderedDict([('GSP_TMOD', ['Polynomial1D', 'Model name used to fit trace']), ('GSP_TORD', [2, 'Degree of the model  ...

# %%
# %matplotlib inline

fig, (ax1, ax2) = plt.subplots(2, 1,sharex=True, figsize=(18, 20))
x,y = ccd.data.shape

ax1.imshow(ccd.data, cmap='gray', clim=(0, 500))
ax1.set_title("Data with sky lines - {} targets".format(len(all_traces)))
for trace, profile, info in all_traces:
    if info['GSP_TERR'][0] > 3:
        color_code = 'b'
    elif info['GSP_TERR'][0] == 0.:
        color_code = 'g'
    else:
        color_code = 'r'
    ax1.plot(range(y), trace(range(y)), color=color_code)

ax2.imshow(copy_ccd.data,  cmap='gray', clim=(0, 500))
ax2.set_title("Data with sky lines removed - {} targets".format(len(all_traces_cleaned)))
for ctrace, profile, info in all_traces_cleaned:
    if info['GSP_TERR'][0] > 3:
        color_code = 'b'
    elif info['GSP_TERR'][0] == 0.:
        color_code = 'g'
    else:
        color_code = 'r'
    
    ax2.plot(range(y), ctrace(range(y)), color=color_code)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18,10))

ax.plot(cleaned_spatial_median, color='r', label="cleaned data")
for trace, profile, info in all_traces_cleaned:
    if info['GSP_TERR'][0] > 3:
        color_code = 'b'
    elif info['GSP_TERR'][0] == 0.:
        color_code = 'g'
    else:
        color_code = 'k'
    ax.axvline(profile.mean.value, color=color_code)
ax.legend(loc='best')
plt.show()

# %% [markdown]
# # Notes
#
# No real progress, possible tasks
#
# - Trace sky lines curvature (not sure how it would help)
# - Do afterwards analysis, such as find trace models "crossing" others
# - Estimate average parameters and do sigma clip.

# %% [markdown]
# # Attempt to fix
#
# ## Make histogram of trace model parameters
#
# ### c0

# %%
all_c0 = []
all_gaussian_mean = []
differences = [ ]

for trace, profile, _ in all_traces_cleaned:
    all_c0.append(trace.c0.value)
    all_gaussian_mean.append(profile.mean.value)
    differences.append(profile.mean.value - trace.c0.value)
fig, ax = plt.subplots(figsize=(18, 10))
ax.hist(differences)
print(differences)
# Out:
# [1.8098175760009099, 0.8642833506054899, 1.0439595098656582, 1.4121065515508917, 1.2282828086109703, 0.5437277384123718, 0.7137060640133654, 1.492210575673539, 0.42616469755466824, -30.912458550850317, 1.4125502546041844, 1.273268628458709, 1.2264980253030728, 0.8851655679447958, 0.7679603893074045, 1.0893913485672897, 1.0963636590927308, 1.6048567133271092]

# %% [markdown]
# ### c1

# %%
all_c1 = []

for trace, _, _ in all_traces_cleaned:
    all_c1.append(trace.c1.value)
    
fig, ax = plt.subplots(figsize=(18,10))

ax.hist(all_c1)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  6., 11.]),
#  array([-0.0211867 , -0.01873777, -0.01628884, -0.0138399 , -0.01139097,
#         -0.00894204, -0.0064931 , -0.00404417, -0.00159524,  0.0008537 ,
#          0.00330263]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### C2

# %%
all_c2 = []

for trace, _, _ in all_traces_cleaned:
    all_c2.append(trace.c2.value)
    
fig, ax = plt.subplots(figsize=(18,10))

ax.hist(all_c2)
# Out:
# (array([2., 4., 8., 3., 0., 0., 0., 0., 0., 1.]),
#  array([-1.11694915e-06, -7.08891873e-07, -3.00834600e-07,  1.07222673e-07,
#          5.15279946e-07,  9.23337219e-07,  1.33139449e-06,  1.73945177e-06,
#          2.14750904e-06,  2.55556631e-06,  2.96362358e-06]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Histogram of RMS Error for trace

# %%
all_rms = []
for _, _, info in all_traces_cleaned:
    all_rms.append(info['GSP_TERR'][0])
    
fig, ax = plt.subplots(figsize=(18, 10))

ax.hist(all_rms)
# Out:
# (array([16.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([0.        , 0.34370789, 0.68741578, 1.03112367, 1.37483156,
#         1.71853944, 2.06224733, 2.40595522, 2.74966311, 3.093371  ,
#         3.43707889]),
#  <a list of 10 Patch objects>)

# %%
problematic_trace = None
for trace, profile, info in all_traces_cleaned:
    if info['GSP_TERR'][0] > 3:
        problematic_trace = trace
        print(Fore.RED + "c0 = {:06.2f} c1 = {: .5f} c2 = {: .3E} Center = {:06.2f} RMS = {:.4f}".format(trace.c0.value, 
                                                                                trace.c1.value,
                                                                                trace.c2.value, 
                                                                                profile.mean.value, 
                                                                                trace_info['GSP_TERR'][0]))
# Out:
# c0 = 454.52 c1 = -0.02119 c2 =  2.964E-06 Center = 423.61 RMS = 0.2088

# %%
fig, ax = plt.subplots(figsize=(18, 200))
ax.imshow(copy_ccd.data, cmap='gray', clim=(0,500))
ax.plot(range(copy_ccd.data.shape[1]), problematic_trace(range(copy_ccd.data.shape[1])), color='r')
ax.set_ylim(500, 350)
# Out:
# (500, 350)

# %%
import numpy as np

print(np.median(differences), np.median(all_c1), np.median(all_c2))
# Out:
# 1.0928775038300103 0.0010538499055247341 -9.102561942194634e-08

# %%
problematic_trace.c0.value = 423.61
problematic_trace.c1.value = np.median(all_c1)
problematic_trace.c2.value = np.median(all_c2)

fig, ax = plt.subplots(figsize=(18, 200))
ax.imshow(copy_ccd.data, cmap='gray', clim=(0,500))
ax.plot(range(copy_ccd.data.shape[1]), problematic_trace(range(copy_ccd.data.shape[1])), color='r')
ax.set_ylim(500, 350)
# Out:
# (500, 350)

# %% [markdown]
# # Conclusion
#
# Should be possible clean and even fix problematic traces, in the future it even might be possible to have good guessed traces for very faint targets.
#
# One of the remaining problems is source deblending and potentially the background subtraction.
#
# ## Other things that could/~~should~~ be implemented
#
# - Trace space axis curvature.
